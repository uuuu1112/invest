# %%
from lynch import *

# %%
lynchShareBaseDf
# Out:
#               成交     PER  eps大於0次數  營收年增率超過30%
# 代號   名稱
# 1101 台泥    37.25   46.60       4.0           0
# 1102 亞泥    40.10   10.90       4.0           0
# 1103 嘉泥    21.35     NaN       3.0           3
# 1104 環泥    28.45   11.40       4.0           0
# 1108 幸福    17.05   10.70       4.0           2
# ...          ...     ...       ...         ...
# 9951 皇田    79.50   13.90       4.0           0
# 9955 佳龍    24.25     NaN       0.0           1
# 9958 世紀鋼  164.00  512.00       3.0           2
# 9960 邁達康   29.00    8.01       4.0           0
# 9962 有益    18.65    7.64       4.0           1
#
# [1790 rows x 4 columns]

# %%
lynchGrowth(lynchShareBaseDf)
# Out:
#                 預期報酬率     PER
# 代號   名稱
# 5516 雙喜     -0.948877    9.62
# 2515 中工     -0.948898   29.80
# 2706 第一店    -0.964819   26.90
# 2371 大同     -0.975755   12.30
# 2916 滿心     -0.976807   13.00
# 6122 擎邦     -0.978827   17.80
# 9906 欣巴巴    -0.980299   14.10
# 5508 永信建    -0.982407   11.60
# 2618 長榮航    -0.983224   24.10
# 2633 台灣高鐵   -0.984306   31.70
# 1584 精剛     -0.985242   30.80
# 6234 高僑     -0.985572   34.20
# 1593 祺驊     -0.986505   14.90
# 4754 國碳科    -0.987648   24.00
# 3032 偉訓     -0.988331   19.10
# 3078 僑威     -0.991070   21.90
# 6873 泓德能源-創 -0.992120   16.20
# 3540 曜越     -0.993029   41.30
# 6577 勁豐     -0.993801   21.80
# 8048 德勝     -0.994180   29.90
# 5209 新鼎     -0.994588   16.40
# 5439 高技     -0.994759   26.50
# 4138 曜亞     -0.995404   25.40
# 2540 愛山林    -0.996063   44.10
# 1796 金穎生技   -0.996220   40.00
# 2754 亞洲藏壽司  -0.996954   29.40
# 2227 裕日車    -0.997359   29.20
# 2752 豆府     -0.997399   22.10
# 6235 華孚     -0.997554   52.20
# ...

# %%
from lynch import *

# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

# %%
revenue=Revenue()

# %%
revenue.revenueGrowth(12)
# Out:
# 代號              2317      2330      4938      2382      3231      2324  \
# 名稱                鴻海       台積電        和碩        廣達        緯創        仁寶
# 21M07營收(億)       NaN       NaN       NaN       NaN       NaN       NaN
# 21M08營收(億)       NaN       NaN       NaN       NaN       NaN       NaN
# 21M09營收(億)       NaN       NaN       NaN       NaN       NaN       NaN
# 21M10營收(億)       NaN       NaN       NaN       NaN       NaN       NaN
# 21M11營收(億)       NaN       NaN       NaN       NaN       NaN       NaN
# 21M12營收(億)       NaN       NaN       NaN       NaN       NaN       NaN
# 22M01營收(億)       NaN       NaN       NaN       NaN       NaN       NaN
# 22M02營收(億)       NaN       NaN       NaN       NaN       NaN       NaN
# 22M03營收(億)       NaN       NaN       NaN       NaN       NaN       NaN
# 22M04營收(億)       NaN       NaN       NaN       NaN       NaN       NaN
# 22M05營收(億)       NaN       NaN       NaN       NaN       NaN       NaN
# ...

# %%
lynchGrowth(lynchShareBaseDf)
# Out:
#               預期報酬率
# 代號   名稱
# 2916 滿心       20.0%
# 2371 大同       19.0%
# 5209 新鼎        8.7%
# 1593 祺驊       -1.3%
# 6873 泓德能源-創   -8.5%
# 6577 勁豐      -18.9%
# 6122 擎邦      -25.0%
# 3032 偉訓      -25.7%
# 2752 豆府      -33.3%
# 4138 曜亞      -34.8%
# 4754 國碳科     -35.1%
# 2618 長榮航     -36.2%
# 3078 僑威      -38.3%
# 1584 精剛      -40.5%
# 2706 第一店     -43.2%
# 8048 德勝      -43.6%
# 5439 高技      -45.1%
# 6703 軒郁      -45.8%
# 6291 沛亨      -48.1%
# 2754 亞洲藏壽司   -49.0%
# 2227 裕日車     -49.3%
# 2707 晶華      -50.3%
# 2633 台灣高鐵    -52.4%
# 6472 保瑞      -52.8%
# 3693 營邦      -53.4%
# 6234 高僑      -58.8%
# 3540 曜越      -58.9%
# 1796 金穎生技    -59.3%
# 4763 材料-KY   -64.5%
# 6235 華孚      -72.3%
# 4979 華星光     -76.0%
# 3661 世芯-KY   -80.2%
# 8996 高力      -80.6%
# 5381 合正      -94.4%

# %%
buffett(lynchShareBaseDf)
# Out:
#          內部成長估值報酬率
# 代號   名稱
# 2609 陽明    1710.6%
# 2603 長榮     867.0%
# 1475 業旺     578.4%
# 2641 正德     476.9%
# 2643 捷迅     344.1%
# ...            ...
# 3563 牧德    -156.6%
# 8446 華研    -171.2%
# 3557 嘉威    -262.1%
# 5321 美而快   -314.6%
# 5009 榮剛       nan%
#
# [224 rows x 1 columns]

# %%
beTrueGrowth(lynchShareBaseDf)
# Out:
#             預期成長估值報酬率
# 代號   名稱
# 2371 大同        229.1%
# 5209 新鼎        156.2%
# 6873 泓德能源-創    154.1%
# 6122 擎邦        126.9%
# 2916 滿心        110.3%
# ...               ...
# 6752 叡揚        -98.2%
# 3563 牧德        -98.4%
# 1580 新麥        -98.4%
# 3594 磐儀        -98.8%
# 6561 是方        -99.4%
#
# [215 rows x 1 columns]

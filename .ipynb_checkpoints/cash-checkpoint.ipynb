# %%
from cash import *

# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

# %%
beTrueCash(cashShareBaseDf)
# Out:
#            5年平均股息殖利率 近一年股息殖利率 10年CAGR  5年CAGR  3年CAGR   預期報酬率 DCF預期報酬率
# 代號   名稱
# 8070 長華*       19.8%     5.9%   -5.0%  -30.4%  -41.0%  295.6%   -90.2%
# 6613 朋億*       10.2%     8.1%    nan%   -3.2%   -5.3%  103.8%   -24.9%
# 3093 港建*       10.0%     9.1%    3.3%   40.4%   23.3%   99.1%   170.5%
# 2108 南帝         9.4%     5.5%   14.9%   14.9%   -1.6%   87.3%   -39.5%
# 2545 皇翔         9.3%    11.7%   -4.8%   25.1%   56.5%   86.8%   270.8%
# ...              ...      ...     ...     ...     ...     ...      ...
# 6591 動力-KY      5.0%     7.3%    nan%   14.5%   39.2%    1.0%    55.0%
# 9911 櫻花         5.0%     5.9%   18.1%    7.3%   11.8%    0.8%    -6.1%
# 2392 正崴         5.0%     5.4%   -1.3%    1.9%   -4.2%    0.7%   -46.9%
# 1436 華友聯        5.0%     8.2%    inf%   15.5%   27.2%    0.7%    81.0%
# 6154 順發         5.0%     5.3%   -2.8%   -2.1%   14.5%    0.6%   -43.0%
#
# [205 rows x 7 columns]

# %%
cashShareDf(cashShareBaseDf)
# Out:
#                     成交  2023發放年度    平均股息  發放股息次數  平均股息發放率  10年CAGR    5年CAGR  \
# 代號     名稱
# 8429   金麗-KY     10.45       0.0   0.030     2.0     1.30     -1.0 -1.000000
# 5907   大洋-KY     14.30       0.0   0.978     3.0   -11.50     -1.0 -1.000000
# 2603   長榮       102.00      70.0  18.098     3.0    33.80      inf  2.227109
# 2929   淘帝-KY     10.90       0.0   0.660     2.0    10.82      NaN -1.000000
# 1340   勝悅-KY     12.45       0.0   0.040     1.0    24.80      NaN -1.000000
# ...                ...       ...     ...     ...      ...      ...       ...
# 911622 泰聚亨-DR      NaN       NaN   0.000     0.0      NaN      NaN       NaN
# 911868 同方友友-DR     NaN       NaN   0.000     0.0      NaN      NaN       NaN
# 912000 晨訊科-DR      NaN       NaN   0.020     1.0      NaN      NaN       NaN
# 8916A  光隆甲特        NaN       NaN     NaN     NaN      NaN      NaN       NaN
# 3089   億杰          NaN       NaN     NaN     NaN     0.00      NaN       NaN
#
# ...

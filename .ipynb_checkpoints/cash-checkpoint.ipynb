# %%
from cash import *

# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

# %%
beTrueCash(cashShareBaseDf)
# Out:
#          5年平均股息殖利率 近一年股息殖利率 10年CAGR  5年CAGR  3年CAGR   預期報酬率
# 代號   名稱
# 8070 長華*     19.9%     5.9%   -5.0%  -30.4%  -41.0%  298.2%
# 3093 港建*      9.9%     9.1%    3.3%   40.4%   23.3%   98.5%
# 6613 朋億*      9.3%     7.4%    nan%   -3.2%   -5.3%   85.2%
# 2545 皇翔       9.2%    11.5%   -4.8%   25.1%   56.5%   84.5%
# 2108 南帝       9.2%     5.5%   14.9%   14.9%   -1.6%   84.4%
# ...            ...      ...     ...     ...     ...     ...
# 3703 欣陸       5.1%     9.2%   17.5%   33.0%   71.0%    2.5%
# 3005 神基       5.1%     5.7%   22.4%    8.6%   10.5%    1.6%
# 2606 裕民       5.1%     7.0%    1.8%   20.1%   16.4%    1.0%
# 6154 順發       5.0%     5.3%   -2.8%   -2.1%   14.5%    0.9%
# 8049 晶采       5.0%     7.1%    inf%   16.5%   18.6%    0.4%
#
# [203 rows x 6 columns]

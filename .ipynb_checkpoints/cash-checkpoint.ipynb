# %%
from cash import *

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
beTrueCash(shareDf)
# Out:
#             近一年股息殖利率 平均股息殖利率   預期報酬率
# 代號   名稱
# 8070 長華*        5.9%   19.8%  295.6%
# 6613 朋億*        8.1%   10.2%  103.8%
# 3093 港建*        9.1%   10.0%   99.1%
# 2108 南帝         5.5%    9.4%   87.3%
# 2545 皇翔        11.7%    9.3%   86.8%
# 8482 商億-KY      9.3%    9.3%   85.8%
# 5536 聖暉*        7.7%    9.1%   81.3%
# 3211 順達         7.4%    8.9%   77.9%
# 6641 基士德-KY     7.4%    8.9%   77.1%
# 3040 遠見         6.6%    8.7%   74.3%
# 8481 政伸         7.1%    8.7%   73.9%
# 3679 新至陞       12.0%    8.7%   73.1%
# 4440 宜新實業      10.3%    8.6%   71.8%
# 3090 日電貿       10.4%    8.5%   70.2%
# 1582 信錦         5.3%    8.5%   70.2%
# 5471 松翰         5.5%    8.5%   70.0%
# 2348 海悅         7.8%    8.5%   69.6%
# 3541 西柏        11.0%    8.4%   67.5%
# 2636 台驊投控      14.2%    8.3%   66.3%
# 1558 伸興         5.2%    8.2%   64.2%
# 5015 華祺        13.0%    8.1%   63.0%
# 6210 慶生         6.0%    8.1%   62.6%
# 5609 中菲行       14.8%    8.0%   59.8%
# 5220 萬達光電       6.3%    7.9%   58.6%
# ...

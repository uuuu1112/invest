# %%
from cash import *

# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

# %%
beTrueCash(cashShareBaseDf)
# Out:
#            5年平均股息殖利率 近一年股息殖利率 10年CAGR  5年CAGR  3年CAGR   預期報酬率
# 代號   名稱
# 8070 長華*       20.0%     5.9%   -5.0%  -30.4%  -41.0%  300.1%
# 3093 港建*       10.0%     9.2%    3.3%   40.4%   23.3%  100.9%
# 8482 商億-KY      9.3%     9.4%    nan%   -2.3%    1.0%   86.0%
# 2108 南帝         9.3%     5.5%   14.9%   14.9%   -1.6%   85.5%
# 2545 皇翔         9.2%    11.5%   -4.8%   25.1%   56.5%   84.0%
# ...              ...      ...     ...     ...     ...     ...
# 3005 神基         5.1%     5.7%   22.4%    8.6%   10.5%    1.7%
# 8271 宇瞻         5.1%     6.3%    7.4%    4.9%    9.0%    1.6%
# 6154 順發         5.1%     5.4%   -2.8%   -2.1%   14.5%    1.5%
# 2107 厚生         5.0%     5.6%   -4.0%   13.0%   13.5%    0.9%
# 3042 晶技         5.0%     7.7%   12.3%   22.9%   40.9%    0.4%
#
# [208 rows x 6 columns]

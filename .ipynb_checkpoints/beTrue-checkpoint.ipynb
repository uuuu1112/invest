# %%
from app.models import *

pd.set_option('display.float_format', '{:.2f}'.format)
# # 設定顯示的最大列數和最大欄數為None，這樣DataFrame的所有列和欄都能夠完整顯示
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

# %%
seasonStock=SeasonStock()
revenue=Revenue()
shortTerm=ShortTerm(seasonStock,revenue)

# %%
idList=['2317','6491','3665','3413','4958','5871','5009','6804','5283','9802','3533','6669','5289','3034','4736']
shortTerm.priceGoal().loc[idList]
# Out:
#                 成交  近4季EPS  過去3.5年的複合成長率低值  內部成長率  過去3個月的年增率最小值  平均成長率  潛在成長率  \
# 代號   名稱
# 2317 鴻海     106.00    9.00            0.00   0.00         -0.20  -0.00   0.00
# 6491 晶碩     396.00   22.10            0.30   0.10         -0.10   0.10   0.10
# 3665 貿聯-KY  256.50     NaN            0.20   0.10         -0.10   0.10  -0.30
# 3413 京鼎     190.00   23.00            0.10   0.10         -0.30  -0.00  -0.10
# 4958 臻鼎-KY  100.50   10.70            0.10   0.10         -0.20   0.00  -0.00
# 5871 中租-KY  183.50     NaN            0.10   0.10          0.10   0.10  -0.30
# 5009 榮剛      45.00    4.90            0.50    NaN          0.00   0.30  -0.00
# 6804 明係      57.40    5.90            0.40   0.10         -0.30   0.10  -0.00
# 5283 禾聯碩    108.50    8.60           -0.00   0.00         -0.20  -0.10   0.00
# 9802 鈺齊-KY  131.00     NaN            0.30   0.20         -0.70  -0.10  -0.30
# 3533 嘉澤     826.00   52.40            0.40   0.10         -0.20   0.10   0.10
# ...

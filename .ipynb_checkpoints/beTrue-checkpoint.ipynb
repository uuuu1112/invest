# %%
from app.models import *

pd.set_option('display.float_format', '{:.2f}'.format)
# # 設定顯示的最大列數和最大欄數為None，這樣DataFrame的所有列和欄都能夠完整顯示
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

# %%
seasonStock=SeasonStock()
revenue=Revenue()
cashList=CashList('on')
baseInfo=BaseInfo()
shortTerm=ShortTerm(seasonStock,revenue,cashList,baseInfo)

# %%
shortTermExpectEarn=shortTerm.expectEarn()

# %%
shortTermExpectEarn
# Out:
#               成交     產業別  近4季EPS  過去3.5年的複合成長率低值  內部成長率  過去3個月的年增率最小值  平均成長率  \
# 代號   名稱
# 2603 長榮   105.00     航運業   33.36            0.40   0.06         -0.40   0.19
# 2609 陽明    42.20     航運業   18.69             NaN   0.15         -0.40   0.06
# 2718 晶悅    45.20   建材營造業    6.11             NaN   0.27          0.40   0.34
# 6171 大城地產  21.20   建材營造業    2.82            0.40   0.12           NaN   0.30
# 8420 明揚    58.00    運動休閒   13.03            0.40   0.21         -0.26   0.15
# ...          ...     ...     ...             ...    ...           ...    ...
# 3432 台端    10.60  電子零組件業  -39.72             NaN  -0.40         -0.40  -0.40
# 3666 光耀    28.40     光電業   -9.72            0.40  -0.40          0.38   0.14
# 4123 晟德    45.85   生技醫療業   -7.04             NaN   0.28          0.40   0.36
# 3481 群創    11.65     光電業   -3.74            0.16    NaN          0.17   0.19
# 6526 達發   419.00     NaN    8.35             NaN    NaN           NaN    NaN
#
#            潛在成長率        短期評估     目標價    預期報酬率
# 代號   名稱
# 2603 長榮    -0.26  供給變大，又供過於求  834.73   695.0%
# 2609 陽明    -0.33  供給變小，又供不應求  283.39   571.5%
# 2718 晶悅    -0.10  供給變小，又供過於求  263.34   482.6%
# 6171 大城地產  -0.07  供給變大，又供過於求  106.19   400.9%
# 8420 明揚    -0.21  供給變小，又供過於求  287.39   395.5%
# ...          ...         ...     ...      ...
# 3432 台端    -0.33              -69.82  -758.7%
# 3666 光耀    -0.33  供給變小，又供不應求 -202.18  -811.9%
# 4123 晟德    -0.33  供給變大，又供過於求 -328.72  -816.9%
# 3481 群創    -0.33  供給變小，又供不應求  -95.34  -918.4%
# 6526 達發     0.38         NaN     NaN     nan%
#
# [1776 rows x 11 columns]

# %%
idList=['2317','6491','3665','3413','4958','5871','5009','6804','5283','9802','3533','6669','5289','3034','4736','3090']
shortTermExpectEarn.loc[idList]
# Out:
#                 成交       產業別  近4季EPS  過去3.5年的複合成長率低值  內部成長率  過去3個月的年增率最小值  \
# 代號   名稱
# 2317 鴻海      98.30     其他電子業    8.97            0.05   0.04         -0.20
# 6491 晶碩     386.00     生技醫療業   22.10            0.34   0.14         -0.13
# 3665 貿聯-KY  265.50     其他電子業   20.74            0.17   0.12         -0.13
# 3413 京鼎     185.50      半導體業   22.98            0.13   0.10         -0.30
# 4958 臻鼎-KY   96.40    電子零組件業   10.75            0.15   0.07         -0.22
# 5871 中租-KY  171.00       其他業   15.72            0.14   0.12          0.11
# 5009 榮剛      44.65      鋼鐵工業    4.85            0.40   0.10          0.01
# 6804 明係      55.00      運動休閒    5.87            0.39   0.09         -0.32
# 5283 禾聯碩    109.00      電器電纜    8.60           -0.03   0.03         -0.19
# 9802 鈺齊-KY  134.00      運動休閒   15.49            0.26   0.19         -0.40
# 3533 嘉澤     835.00    電子零組件業   52.38            0.40   0.15         -0.17
# 6669 緯穎    1665.00  電腦及週邊設備業   81.12            0.31   0.16         -0.40
# 5289 宜鼎     280.50  電腦及週邊設備業   17.16            0.15   0.09         -0.28
# 3034 聯詠     429.50      半導體業   32.18            0.40   0.07          0.40
# 4736 泰博     143.50     生技醫療業   18.04            0.40   0.09         -0.40
# 3090 日電貿     57.40    電子零組件業    6.73            0.18   0.08          0.00
#
#             平均成長率  潛在成長率        短期評估     目標價   預期報酬率
# 代號   名稱
# 2317 鴻海      0.01  -0.00  供給變小，又供不應求  109.89   11.8%
# 6491 晶碩      0.13   0.10  供給變小，又供不應求  446.04   15.6%
# 3665 貿聯-KY   0.09   0.03  供給變小，又供不應求  348.78   31.4%
# 3413 京鼎      0.02  -0.07  供給變小，又供不應求  292.49   57.7%
# 4958 臻鼎-KY   0.05  -0.05  供給變小，又供不應求  156.31   62.1%
# 5871 中租-KY   0.15  -0.00              346.38  102.6%
# 5009 榮剛      0.19  -0.05  供給變小，又供過於求  124.56  179.0%
# 6804 明係      0.05  -0.05  供給變小，又供過於求   86.20   56.7%
# 5283 禾聯碩     0.01   0.03  供給變小，又供過於求  106.50   -2.3%
# 9802 鈺齊-KY   0.05  -0.05  供給變小，又供不應求  226.85   69.3%
# 3533 嘉澤      0.14   0.08  供給變小，又供不應求 1106.71   32.5%
# 6669 緯穎      0.04   0.15  供給變小，又供不應求 1128.78  -32.2%
# 5289 宜鼎      0.02   0.08  供給變小，又供不應求  214.64  -23.5%
# 3034 聯詠      0.35   0.03  供給變小，又供過於求 1436.69  234.5%
# 4736 泰博      0.11  -0.07  供給變小，又供過於求  337.89  135.5%
# 3090 日電貿     0.16  -0.05  供給變小，又供不應求  154.19  168.6%

# %%
idList2=['9917','8916','6227','9907','3209','5283','3029']
shortTermExpectEarn.loc[idList2]
# Out:
#              成交    產業別  近4季EPS  過去3.5年的複合成長率低值  內部成長率  過去3個月的年增率最小值  平均成長率  \
# 代號   名稱
# 9917 中保科 115.50    其他業    5.63            0.03   0.03          0.11   0.10
# 8916 光隆   51.80    其他業    5.57            0.17   0.07         -0.40   0.01
# 6227 茂綸   40.95  電子通路業    5.68            0.30   0.09         -0.11   0.15
# 9907 統一實  15.65    其他業    0.89            0.30  -0.00         -0.32   0.04
# 3209 全科   33.55  電子通路業    3.22            0.21   0.05         -0.26   0.06
# 5283 禾聯碩 109.00   電器電纜    8.60           -0.03   0.03         -0.19   0.01
# 3029 零壹   61.40  資訊服務業    4.27            0.12   0.02         -0.12   0.05
#
#           潛在成長率        短期評估    目標價   預期報酬率
# 代號   名稱
# 9917 中保科   0.15  供給變小，又供不應求  98.51  -14.7%
# 8916 光隆   -0.05  供給變小，又供不應求  67.08   29.5%
# 6227 茂綸   -0.10  供給變小，又供不應求 122.36  198.8%
# 9907 統一實   0.11  供給變小，又供過於求  12.21  -22.0%
# 3209 全科   -0.03  供給變大，又供過於求  47.96   43.0%
# 5283 禾聯碩   0.03  供給變小，又供過於求 106.50   -2.3%
# 3029 零壹    0.05  供給變大，又供過於求  61.83    0.7%

# %%
idList3=['3406','5536','1537','1795','5209','9942','3293']
shortTermExpectEarn.loc[idList3]
# Out:
#              成交    產業別  近4季EPS  過去3.5年的複合成長率低值  內部成長率  過去3個月的年增率最小值  平均成長率  \
# 代號   名稱
# 3406 玉晶光 383.00    光電業   25.20            0.05   0.09          0.10   0.10
# 5536 聖暉* 182.00  其他電子業   18.65           -0.04   0.09         -0.32  -0.01
# 1537 廣隆  131.00   電機機械    7.68           -0.04   0.01         -0.26  -0.03
# 1795 美時  230.00  生技醫療業   18.35            0.40   0.25         -0.40   0.09
# 5209 新鼎  174.00    其他業   12.51            0.22   0.09          0.33   0.24
# 9942 茂順  128.50    其他業   10.44            0.04   0.08          0.04   0.09
# 3293 鈊象  623.00  文化創意業   40.74            0.11   0.07          0.18   0.17
#
#           潛在成長率         短期評估    目標價   預期報酬率
# 代號   名稱
# 3406 玉晶光   0.07  供給變變大，又供不應求 453.94   18.5%
# 5536 聖暉*  -0.03   供給變大，又供過於求 206.16   13.3%
# 1537 廣隆    0.10   供給變小，又供不應求  79.64  -39.2%
# 1795 美時    0.03   供給變大，又供過於求 309.10   34.4%
# 5209 新鼎    0.05              384.61  121.0%
# 9942 茂順    0.02   供給變小，又供不應求 177.32   38.0%
# 3293 鈊象    0.07   供給變小，又供不應求 966.36   55.1%

# %%
dcf.dcfEstimate(32,0.12)
# Out:
# 615.4061651526533

# %%
dcf.dcfEstimate(8.6,0.05)
# Out:
# 124.3742225385902

# %%
dcf.dcfEstimate(1,0)
# Out:
# 11.70753363841267

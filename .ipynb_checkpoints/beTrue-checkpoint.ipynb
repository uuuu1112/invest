# %%
from app.models import *

pd.set_option('display.float_format', '{:.2f}'.format)
# # 設定顯示的最大列數和最大欄數為None，這樣DataFrame的所有列和欄都能夠完整顯示
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

# %%
lynchInvest=LynchInvest()

# %%
lynchInvest.baseDf()
# Out:
#                最小營收年增率  最小EPS       產業別
# 代號   名稱
# 2317 鴻海          -0.20   0.93     其他電子業
# 2330 台積電         -0.11   7.01      半導體業
# 4938 和碩          -0.28   1.13  電腦及週邊設備業
# 2382 廣達          -0.33   1.68  電腦及週邊設備業
# 2324 仁寶          -0.33   0.25  電腦及週邊設備業
# ...                ...    ...       ...
# 6171 大城地產          NaN  -0.09     建材營造業
# 6547 高端疫苗        -1.00  -2.22     生技醫療業
# 6550 北極星藥業-KY      NaN    NaN     生技醫療業
# 1213 大飲          -1.07  -0.72      食品工業
# 5864 致和證         -8.85   0.19       證券業
#
# [1793 rows x 3 columns]

# %%
from app.cashList import *

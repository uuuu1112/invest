# %%
from app.models import *

pd.set_option('display.float_format', '{:.2f}'.format)
# # 設定顯示的最大列數和最大欄數為None，這樣DataFrame的所有列和欄都能夠完整顯示
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

# %%
seasonStock=SeasonStock()
revenue=Revenue()
cashList=CashList('on')
shortTerm=ShortTerm(seasonStock,revenue,cashList)

# %%
shortTermExpectEarn=shortTerm.expectEarn()

# %%
shortTermExpectEarn
# Out:
#               成交  近4季EPS  過去3.5年的複合成長率低值  內部成長率  過去3個月的年增率最小值  平均成長率  潛在成長率  \
# 代號   名稱
# 2603 長榮   102.50   33.36            0.40   0.06         -0.40   0.19  -0.26
# 2609 陽明    42.30   18.69             NaN   0.15         -0.40   0.06  -0.33
# 2718 晶悅    44.05    6.11             NaN   0.27          0.40   0.34  -0.10
# 6171 大城地產  21.30    2.82            0.40   0.12           NaN   0.30  -0.07
# 8420 明揚    59.90   13.03            0.40   0.21         -0.26   0.15  -0.17
# ...          ...     ...             ...    ...           ...    ...    ...
# 2390 云辰    13.70   -5.40            0.40  -0.20          0.02   0.07  -0.33
# 3432 台端    10.60  -39.72             NaN  -0.40         -0.40  -0.40  -0.33
# 4123 晟德    44.40   -7.04             NaN   0.28          0.40   0.36  -0.33
# 3666 光耀    26.60   -9.72            0.40  -0.40          0.38   0.14  -0.33
# 3481 群創    12.10   -3.74            0.16    NaN          0.17   0.19  -0.33
#
#                  短期評估     目標價    預期報酬率
# ...

# %%
idList=['2317','6491','3665','3413','4958','5871','5009','6804','5283','9802','3533','6669','5289','3034','4736','3090']
shortTermExpectEarn.loc[idList]
# Out:
#                 成交  近4季EPS  過去3.5年的複合成長率低值  內部成長率  過去3個月的年增率最小值  平均成長率  潛在成長率  \
# 代號   名稱
# 2317 鴻海     105.50    8.97            0.05   0.04         -0.20   0.01   0.02
# 6491 晶碩     385.00   22.10            0.34   0.14         -0.13   0.13   0.10
# 3665 貿聯-KY  264.50   20.74            0.17   0.12         -0.13   0.09   0.03
# 3413 京鼎     186.50   22.98            0.13   0.10         -0.30   0.02  -0.07
# 4958 臻鼎-KY  101.50   10.75            0.15   0.07         -0.22   0.05  -0.05
# 5871 中租-KY  179.00   15.72            0.14   0.12          0.11   0.15  -0.00
# 5009 榮剛      44.00    4.85            0.40   0.10          0.01   0.19  -0.05
# 6804 明係      56.00    5.87            0.39   0.09         -0.32   0.05  -0.03
# 5283 禾聯碩    108.50    8.60           -0.03   0.03         -0.19   0.01   0.03
# 9802 鈺齊-KY  129.50   15.49            0.26   0.19         -0.40   0.05  -0.07
# 3533 嘉澤     824.00   52.38            0.40   0.15         -0.17   0.14   0.08
# ...

# %%
idList2=['9917','8916','6227','9907','3209','5283','3029']
shortTermExpectEarn.loc[idList2]
# Out:
#              成交  近4季EPS  過去3.5年的複合成長率低值  內部成長率  過去3個月的年增率最小值  平均成長率  潛在成長率  \
# 代號   名稱
# 9917 中保科 114.50    5.63            0.03   0.03          0.11   0.10   0.14
# 8916 光隆   51.70    5.57            0.17   0.07         -0.40   0.01  -0.05
# 6227 茂綸   40.60    5.68            0.30   0.09         -0.11   0.15  -0.10
# 9907 統一實  16.00    0.89            0.30  -0.00         -0.32   0.04   0.11
# 3209 全科   35.50    3.22            0.21   0.05         -0.26   0.05  -0.00
# 5283 禾聯碩 108.50    8.60           -0.03   0.03         -0.19   0.01   0.03
# 3029 零壹   61.50    4.27            0.12   0.02         -0.12   0.05   0.05
#
#                 短期評估    目標價   預期報酬率
# 代號   名稱
# 9917 中保科  供給變小，又供不應求  98.65  -13.8%
# 8916 光隆   供給變小，又供不應求  67.11   29.8%
# 6227 茂綸   供給變小，又供不應求 122.59  201.9%
# 9907 統一實  供給變小，又供過於求  12.16  -24.0%
# 3209 全科   供給變大，又供過於求  47.34   33.4%
# 5283 禾聯碩  供給變小，又供過於求 106.66   -1.7%
# 3029 零壹   供給變大，又供過於求  61.81    0.5%

# %%
idList3=['3406','5536','1537','1795','5209','9942','3293']
shortTermExpectEarn.loc[idList3]
# Out:
#              成交  近4季EPS  過去3.5年的複合成長率低值  內部成長率  過去3個月的年增率最小值  平均成長率  潛在成長率  \
# 代號   名稱
# 3406 玉晶光 375.50   25.20            0.05   0.09          0.10   0.10   0.07
# 5536 聖暉* 176.50   18.65           -0.04   0.09         -0.32  -0.01  -0.05
# 1537 廣隆  133.50    7.68           -0.04   0.01         -0.26  -0.03   0.10
# 1795 美時  210.50   18.35            0.40   0.25         -0.40   0.09  -0.00
# 5209 新鼎  179.50   12.51            0.22   0.09          0.33   0.24   0.05
# 9942 茂順  126.50   10.44            0.04   0.08          0.04   0.09   0.02
# 3293 鈊象  617.00   40.74            0.11   0.07          0.18   0.17   0.07
#
#                  短期評估    目標價   預期報酬率
# 代號   名稱
# 3406 玉晶光  供給變變大，又供不應求 454.74   21.1%
# 5536 聖暉*   供給變大，又供過於求 208.26   18.0%
# 1537 廣隆    供給變小，又供不應求  79.18  -40.7%
# 1795 美時    供給變大，又供過於求 309.70   47.1%
# 5209 新鼎               383.34  113.6%
# 9942 茂順    供給變小，又供不應求 177.73   40.5%
# 3293 鈊象    供給變小，又供不應求 968.25   56.9%

# %%
dcf.dcfEstimate(1,0.07)
# Out:
# 15.709131168465262

# %%
dcf.dcfEstimate(8.6,0.05)
# Out:
# 124.3742225385902

# %%
dcf.dcfEstimate(1,0)
# Out:
# 11.70753363841267

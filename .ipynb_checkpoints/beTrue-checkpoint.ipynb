# %%
from app.models import *

pd.set_option('display.float_format', '{:.2f}'.format)
# # 設定顯示的最大列數和最大欄數為None，這樣DataFrame的所有列和欄都能夠完整顯示
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

# %%
seasonStock=SeasonStock()
revenue=Revenue()
shortTerm=ShortTerm(seasonStock,revenue)

# %%
shortTerm.baseDf()
# Out:
#                  成交  近4季EPS  過去3.5年的複合成長率低值  內部成長率  過去3個月的年增率最小值  平均成長率  \
# 代號   名稱
# 8429 金麗-KY    10.65   -0.81            0.50  -0.03          0.12   0.20
# 5907 大洋-KY    12.30   -6.40             NaN  -0.10         -0.18  -0.14
# 3673 TPK-KY   34.40    0.92           -0.27   0.01         -0.37  -0.21
# 1340 勝悅-KY    11.60   -2.70           -0.01  -0.09          0.14   0.02
# 1337 再生-KY     7.04   -1.68           -0.10  -0.09          0.00  -0.06
# ...             ...     ...             ...    ...           ...    ...
# 6409 旭隼     1590.00   52.88            0.24   0.11         -0.34   0.00
# 3443 創意     1715.00   30.89            0.34   0.30          0.10   0.25
# 5274 信驊     2870.00   37.52            0.29   0.09         -0.46  -0.03
# 4943 康控-KY    14.45   -5.25             NaN  -1.79         -0.16  -0.98
# 3529 力旺     2250.00   19.60            0.22   0.03         -0.13   0.04
#
#              潛在成長率        短期評估
# 代號   名稱
# 8429 金麗-KY   -0.33  供給變小，又供不應求
# 5907 大洋-KY   -0.33  供給變小，又供不應求
# 3673 TPK-KY   0.30  供給變小，又供不應求
# 1340 勝悅-KY   -0.33  供給變小，又供過於求
# 1337 再生-KY   -0.33  供給變小，又供不應求
# ...            ...         ...
# 6409 旭隼       0.24  供給變小，又供不應求
# 3443 創意       0.40  供給變小，又供不應求
# 5274 信驊       0.40  供給變大，又供過於求
# 4943 康控-KY   -0.33  供給變小，又供不應求
# 3529 力旺       0.40         NaN
#
# [1793 rows x 8 columns]

# %%
shortTerm.priceGoal()
# Out:
#                  成交  近4季EPS  過去3.5年的複合成長率低值  內部成長率  過去3個月的年增率最小值  平均成長率  \
# 代號   名稱
# 8429 金麗-KY    10.65   -0.81            0.50  -0.03          0.12   0.20
# 5907 大洋-KY    12.30   -6.40             NaN  -0.10         -0.18  -0.14
# 3673 TPK-KY   34.40    0.92           -0.27   0.01         -0.37  -0.21
# 1340 勝悅-KY    11.60   -2.70           -0.01  -0.09          0.14   0.02
# 1337 再生-KY     7.04   -1.68           -0.10  -0.09          0.00  -0.06
# ...             ...     ...             ...    ...           ...    ...
# 6409 旭隼     1590.00   52.88            0.24   0.11         -0.34   0.00
# 3443 創意     1715.00   30.89            0.34   0.30          0.10   0.25
# 5274 信驊     2870.00   37.52            0.29   0.09         -0.46  -0.03
# 4943 康控-KY    14.45   -5.25             NaN  -1.79         -0.16  -0.98
# 3529 力旺     2250.00   19.60            0.22   0.03         -0.13   0.04
#
#              潛在成長率        短期評估    目標價
# 代號   名稱
# 8429 金麗-KY   -0.33  供給變小，又供不應求 -20.96
# 5907 大洋-KY   -0.33  供給變小，又供不應求 -40.40
# 3673 TPK-KY   0.30  供給變小，又供不應求   4.12
# 1340 勝悅-KY   -0.33  供給變小，又供過於求 -33.68
# 1337 再生-KY   -0.33  供給變小，又供不應求 -15.01
# ...            ...         ...    ...
# 6409 旭隼       0.24  供給變小，又供不應求 625.90
# 3443 創意       0.40  供給變小，又供不應求 970.05
# 5274 信驊       0.40  供給變大，又供過於求 389.64
# 4943 康控-KY   -0.33  供給變小，又供不應求  -0.12
# 3529 力旺       0.40         NaN 275.18
#
# [1793 rows x 9 columns]

# %%
shortTermExpectEarn=shortTerm.expectEarn()

# %%
shortTermExpectEarn
# Out:
#               成交  近4季EPS  過去3.5年的複合成長率低值  內部成長率  過去3個月的年增率最小值  平均成長率  潛在成長率  \
# 代號   名稱
# 2718 晶悅    45.80    6.10             NaN   0.30          0.50   0.40  -0.10
# 6171 大城地產  21.20    2.80            0.50   0.10           NaN   0.30  -0.10
# 8420 明揚    60.10   13.00            0.50   0.20         -0.30   0.10  -0.20
# 2603 長榮   104.00   33.40            0.50   0.10         -0.60  -0.00  -0.30
# 1108 幸福    14.20    1.70            0.50   0.00          0.10   0.20  -0.10
# ...          ...     ...             ...    ...           ...    ...    ...
# 3481 群創    12.20   -3.70            0.20    NaN          0.20   0.20  -0.30
# 3666 光耀    28.20   -9.70            0.50  -0.40          0.40   0.20  -0.30
# 4123 晟德    45.30   -7.00             NaN   0.30          0.50   0.40  -0.30
# 6020 大展證   18.50    0.70             NaN   0.00        -13.10  -6.60   0.20
# 6026 福邦證   11.60    0.60             NaN   0.00        -52.50 -26.20   0.10
#
#                  短期評估          目標價          預期報酬率
# 代號   名稱
# 2718 晶悅    供給變小，又供過於求       312.60         582.5%
# 6171 大城地產  供給變大，又供過於求       102.50         383.5%
# 8420 明揚    供給變小，又供過於求       281.30         368.1%
# 2603 長榮    供給變大，又供過於求       355.30         241.6%
# 1108 幸福    供給變小，又供過於求        46.70         228.9%
# ...               ...          ...            ...
# 3481 群創    供給變小，又供不應求       -85.80        -803.3%
# 3666 光耀    供給變小，又供不應求      -213.00        -855.3%
# 4123 晟德    供給變大，又供過於求      -366.30        -908.6%
# 6020 大展證          NaN    -31496.00     -170348.6%
# 6026 福邦證          NaN -55748023.90  -480586512.9%
#
# [1774 rows x 10 columns]

# %%
idList=['2317','6491','3665','3413','4958','5871','5009','6804','5283','9802','3533','6669','5289','3034','4736']
shortTermExpectEarn.loc[idList]
# Out:
#                 成交  近4季EPS  過去3.5年的複合成長率低值  內部成長率  過去3個月的年增率最小值  平均成長率  潛在成長率  \
# 代號   名稱
# 2317 鴻海     107.00    9.00            0.00   0.00         -0.20  -0.00   0.00
# 6491 晶碩     388.00   22.10            0.30   0.10         -0.10   0.10   0.10
# 3665 貿聯-KY  257.00   20.70            0.20   0.10         -0.10   0.10   0.00
# 3413 京鼎     191.50   23.00            0.10   0.10         -0.30  -0.00  -0.10
# 4958 臻鼎-KY  102.00   10.70            0.10   0.10         -0.20   0.00  -0.00
# 5871 中租-KY  182.50   15.70            0.10   0.10          0.10   0.10   0.00
# 5009 榮剛      45.60    4.90            0.50   0.10          0.00   0.20  -0.00
# 6804 明係      56.60    5.90            0.40   0.10         -0.30   0.10  -0.00
# 5283 禾聯碩    108.50    8.60           -0.00   0.00         -0.20  -0.10   0.00
# 9802 鈺齊-KY  132.00   15.50            0.30   0.20         -0.70  -0.10  -0.00
# 3533 嘉澤     837.00   52.40            0.40   0.10         -0.20   0.10   0.10
# 6669 緯穎    1590.00   81.10            0.30   0.20         -0.50  -0.00   0.10
# 5289 宜鼎     288.00   17.20            0.10   0.10         -0.30  -0.00   0.10
# 3034 聯詠     431.50   32.20            0.40   0.10          0.40   0.30   0.00
# 4736 泰博     148.00   18.00            0.50   0.10         -0.70  -0.10  -0.10
#
#                   短期評估     目標價   預期報酬率
# 代號   名稱
# 2317 鴻海     供給變小，又供不應求   90.10  -15.8%
# 6491 晶碩     供給變小，又供不應求  421.40    8.6%
# 3665 貿聯-KY  供給變小，又供不應求  304.40   18.4%
# 3413 京鼎     供給變小，又供不應求  242.30   26.5%
# 4958 臻鼎-KY  供給變小，又供不應求  126.20   23.7%
# 5871 中租-KY              307.70   68.6%
# 5009 榮剛     供給變小，又供過於求  129.60  184.2%
# 6804 明係     供給變小，又供過於求   86.20   52.3%
# 5283 禾聯碩    供給變小，又供過於求   77.00  -29.0%
# 9802 鈺齊-KY  供給變小，又供不應求  134.30    1.7%
# 3533 嘉澤     供給變小，又供不應求 1058.60   26.5%
# 6669 緯穎     供給變小，又供不應求  907.10  -42.9%
# 5289 宜鼎     供給變小，又供不應求  186.80  -35.1%
# 3034 聯詠     供給變小，又供過於求 1201.40  178.4%
# 4736 泰博     供給變小，又供過於求  165.30   11.7%

# %%
idList2=['9917','8916','6227','9907','3209','5283','3029']
shortTermExpectEarn.loc[idList2]
# Out:
#              成交  近4季EPS  過去3.5年的複合成長率低值  內部成長率  過去3個月的年增率最小值  平均成長率  潛在成長率  \
# 代號   名稱
# 9917 中保科 116.00    5.60            0.00   0.00          0.10   0.10   0.20
# 8916 光隆   52.00    5.60            0.20   0.10         -0.40  -0.10  -0.00
# 6227 茂綸   41.40    5.70            0.30   0.10         -0.10   0.10  -0.10
# 9907 統一實  16.10    0.90            0.30  -0.00         -0.30  -0.00   0.10
# 3209 全科   34.00    3.20            0.20   0.00         -0.30  -0.00  -0.00
# 5283 禾聯碩 108.50    8.60           -0.00   0.00         -0.20  -0.10   0.00
# 3029 零壹   65.40    4.30            0.10   0.00         -0.10   0.00   0.10
#
#                 短期評估   目標價   預期報酬率
# 代號   名稱
# 9917 中保科  供給變小，又供不應求 84.00  -27.6%
# 8916 光隆   供給變小，又供不應求 49.20   -5.4%
# 6227 茂綸   供給變小，又供不應求 97.50  135.5%
# 9907 統一實  供給變小，又供過於求 10.10  -37.3%
# 3209 全科   供給變大，又供過於求 37.60   10.6%
# 5283 禾聯碩  供給變小，又供過於求 77.00  -29.0%
# 3029 零壹   供給變大，又供過於求 51.30  -21.6%

# %%
idList3=['3406','5536','1537','1795','5209','9942','3293']
shortTermExpectEarn.loc[idList3]
# Out:
#              成交  近4季EPS  過去3.5年的複合成長率低值  內部成長率  過去3個月的年增率最小值  平均成長率  潛在成長率  \
# 代號   名稱
# 3406 玉晶光 383.50   25.20            0.10   0.10          0.10   0.10   0.10
# 5536 聖暉* 180.00   18.70           -0.00   0.10         -0.30  -0.10  -0.00
# 1537 廣隆  133.00    7.70           -0.00   0.00         -0.30  -0.10   0.10
# 1795 美時  220.50   18.30            0.50   0.20         -0.70   0.00   0.00
# 5209 新鼎  177.50   12.50            0.20   0.10          0.30   0.20   0.00
# 9942 茂順  132.00   10.40            0.00   0.10          0.00   0.10   0.00
# 3293 鈊象  622.00   40.70            0.10   0.10          0.20   0.10   0.10
#
#                  短期評估    目標價   預期報酬率
# 代號   名稱
# 3406 玉晶光  供給變變大，又供不應求 415.20    8.3%
# 5536 聖暉*   供給變大，又供過於求 147.90  -17.8%
# 1537 廣隆    供給變小，又供不應求  58.00  -56.4%
# 1795 美時    供給變大，又供過於求 238.70    8.3%
# 5209 新鼎               344.90   94.3%
# 9942 茂順    供給變小，又供不應求 153.10   16.0%
# 3293 鈊象    供給變小，又供不應求 787.50   26.6%

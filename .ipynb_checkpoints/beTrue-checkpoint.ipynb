# %%
from growth import *

# %%
pastGrowth=PastGrowth()

# %%
pastGrowth.eps4Season
# Out:
#         排名       代號     名稱      成交    漲跌價   漲跌幅  平均EPS(元)  20Q2EPS(元)  \
# 0        1  ="3008"    大立光  2160.0  -30.0 -1.37     38.85       37.19
# 1        2  ="2603"     長榮   105.0   -0.5 -0.47     10.20        0.66
# 2        3  ="6669"     緯穎  1555.0 -170.0 -9.86     15.86       12.41
# 3        4  ="2454"    聯發科   709.0   -4.0 -0.56     14.85        4.58
# 4        5  ="3533"     嘉澤   736.0    6.0  0.82     10.47        8.69
# ...    ...      ...    ...     ...    ...   ...       ...         ...
# 1780  1781  ="6462"     神盾    99.1   -2.4 -2.36     -0.91        2.46
# 1781  1782  ="2204"     中華    90.2    0.3  0.33      0.09        1.67
# 1782  1783  ="6541"  泰福-KY    67.0   -1.0 -1.47     -1.69       -2.13
# 1783  1784  ="3432"     台端    11.8    0.0  0.00     -1.38        0.08
# 1784  1785  ="2207"    和泰車   738.0  -32.0 -4.16      1.88        5.94
#
#       20Q3EPS(元)  20Q4EPS(元)  21Q1EPS(元)  21Q2EPS(元)  21Q3EPS(元)  21Q4EPS(元)  \
# ...

# %%
from base import *

# %%
seasonEps=SeasonEps()
cash=Cash()

# %%
cacul.nPeriodSum(seasonEps.seasonEpsTrans,4)
# Out:
# 代號             3008    2603     6669    2454    3533     6409    2327  \
# 名稱              大立光      長榮       緯穎     聯發科      嘉澤       旭隼      國巨
# 排名              NaN     NaN      NaN     NaN     NaN      NaN     NaN
# 成交              NaN     NaN      NaN     NaN     NaN      NaN     NaN
# 漲跌價             NaN     NaN      NaN     NaN     NaN      NaN     NaN
# 漲跌幅         2129.63  106.03  1378.14  708.44  747.82  1602.51  471.83
# 平均EPS(元)    2167.48  114.23  1391.00  719.29  753.29  1605.49  474.83
# 20Q2EPS(元)    44.67    9.89  -151.59   14.87   25.98   -44.94   19.18
# 20Q3EPS(元)   118.41   12.09    31.26   27.30   27.44    21.39   23.44
# 20Q4EPS(元)   171.65   15.35    56.75   37.23   32.89    30.13   30.98
# 21Q1EPS(元)   172.42   12.19    50.61   38.59   30.48    26.02   31.11
# 21Q2EPS(元)   157.30   19.62    51.40   51.45   28.64    23.54   36.58
# 21Q3EPS(元)   152.78   33.25    50.14   60.95   30.11    25.12   44.67
# ...

# %%
cash.cashTrans
# Out:
# 代號          2454    2603     6669     3008     5274     6409    3592    3034  \
# 名稱           聯發科      長榮       緯穎      大立光       信驊       旭隼      瑞鼎      聯詠
# 排名          1.00    2.00     3.00     4.00     5.00     6.00    7.00    8.00
# 股價日期         NaN     NaN      NaN      NaN      NaN      NaN     NaN     NaN
# 成交        692.00  101.00  1900.00  2240.00  2535.00  1835.00  321.50  409.50
# 漲跌價        -4.00    2.90   100.00   -30.00    10.00    25.00    3.00    5.00
# 漲跌幅        -0.57    2.96     5.56    -1.32     0.40     1.38    0.94    1.24
# EPS平均      26.85   11.31    44.32   143.68    19.83    21.94   17.63   17.75
# EPS合計     322.10  135.70   265.90  1724.00   237.90   241.30  211.60  213.00
# 股利平均       24.25    7.57    25.01    58.93    16.88    19.54   13.34   14.39
# 股利合計      291.00   90.79   150.00   707.20   202.50   214.90  160.10  172.70
# 2012發放年度    9.00    0.00      NaN    17.00     4.00      NaN    8.00    4.60
# ...

# %%
cagr=CAGR()

# %%
cagr.baseCagr(cash.cashTrans,1)
# Out:
# 代號             2454       2603      6669        3008       5274       6409  \
# 名稱              聯發科         長榮        緯穎         大立光         信驊         旭隼
# 排名              NaN        NaN       NaN         NaN        NaN        NaN
# 股價日期            NaN        NaN       NaN         NaN        NaN        NaN
# 成交              NaN        NaN       NaN         NaN        NaN        NaN
# 漲跌價       -1.005780  -0.971287 -0.947368   -1.013393  -0.996055  -0.986376
# 漲跌幅       -0.857500   0.020690 -0.944400   -0.956000  -0.960000  -0.944800
# EPS平均    -48.105263   2.820946  6.971223 -109.848485  48.575000  14.898551
# EPS合計     10.996276  10.998232  4.999549   10.998886  10.996974   9.998177
# 股利平均      -0.924713  -0.944215 -0.905942   -0.965818  -0.929046  -0.919022
# 股利合計      11.000000  10.993395  4.997601   11.000679  10.996445   9.997953
# 2012發放年度  -0.969072  -1.000000       NaN   -0.975962  -0.980247        NaN
# ...

# %%
from growth import PastGrowth
from base import YearEps

eps=YearEps()
pastGrowth=PastGrowth(eps)

# %%
c.minCagr()
# Out:
# 代號    名稱
# 2330  台積電     24.26%
# 2603  長榮     113.34%
# 2609  陽明     213.78%
# 2317  鴻海       4.97%
# 2454  聯發科     36.82%
#               ...
# 2204  中華      81.46%
# 2867  三商壽       nan%
# 2207  和泰車       nan%
# 2409  友達       6.12%
# 3481  群創      15.96%
# Length: 1789, dtype: object

# %%
pastGrowth.year3Cagr()
# Out:
# 代號    名稱
# 2330  台積電      43.30%
# 2603  長榮     1532.85%
# 2609  陽明         nan%
# 2317  鴻海        7.06%
# 2454  聯發科      71.88%
#                ...
# 2204  中華       81.46%
# 2867  三商壽        nan%
# 2207  和泰車        nan%
# 2409  友達        6.12%
# 3481  群創       15.96%
# Name: 2022EPS(元), Length: 1789, dtype: object

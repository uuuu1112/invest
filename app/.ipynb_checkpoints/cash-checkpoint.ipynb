# %%
from modles import *

# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

# %%
cash=Cash()
dividendRatio=DividendRatio()
today=Today()
cashInvest=CashInvest(cash,dividendRatio,today)

# %%
cashInvest.expectEarn()
# Out:
#             近一年股息殖利率  5年平均股息殖利率  5年最低股息  平均股息發放率    預期報酬率
# 代號   名稱
# 8070 長華*    0.060403   0.204094    1.40    79.96  308.19%
# 3093 港建*    0.096308   0.105297    1.30    83.58  110.59%
# 2545 皇翔     0.120104   0.096084    1.20   663.60   92.17%
# 2108 南帝     0.056180   0.094944    1.80    63.02   89.89%
# 8482 商億-KY  0.094673   0.094155    4.80    78.86   88.31%
# ...              ...        ...     ...      ...      ...
# 9911 櫻花     0.059295   0.050641    2.65    74.72    1.28%
# 8284 三竹     0.067227   0.050555    2.36    75.76    1.11%
# 6138 茂達     0.071429   0.050397    4.20    80.44    0.79%
# 6161 捷波     0.065531   0.050328    0.90    78.76    0.66%
# 5478 智冠     0.071869   0.050144    2.20    78.32    0.29%
#
# [223 rows x 5 columns]
